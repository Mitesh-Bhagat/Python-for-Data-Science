# %% [markdown]
# This box is note box
#
# <img src ="Images/Note.jpg" height="100px" weidth="100px">
#
# Hello This is First Program

# %%
# This is Code Box

print("Hello World")
# Out:
# Hello World

# %%
# This is Code Box

print("Second Line")
# Out:
# Second Line

# %% [markdown]
# Complete
#
# <img src ="Images/complete.png" height="100px" weidth="100px">
#
# Hello This is First Program
